# %%
from pyspark import SparkContext, SparkConf
import sys, time, queue, operator, copy


class GraphNode:

    def __init__(self, ids, parents, children, shortest_path, weight, level):
        self.ids = ids
        self.parents = parents
        self.children = children
        self.shortest_path = shortest_path
        self.weight = weight
        self.level = level

    # def __hash__(self):
    #     return hash(self.ids)
    #
    # def __eq__(self, other):
    #     return self.__class__ == other.__class__ and self.ids == other.ids


class BFSTree:

    def __int__(self, root, tree):
        self.root = root
        self.tree = tree


def construct_graph(x):

    neighbor = set()

    same_review_num = 0

    for k,v in user_business_map.items():

        if k != x[0]:

            same_review_num = len(v.intersection(x[1]))

            if same_review_num >= 7:

                neighbor.add(k)

    return (x[0], neighbor)


def bfs(root, graph):

    visited = {}

    root_node = GraphNode(root, set(), set(), 0, 0, 0)

    visited[root] = root_node

    level = 1

    q = queue.Queue()

    q.put(root)

    while not q.empty():

        q_size = q.qsize()

        for x in range(q_size):

            curr_node = q.get()

            for nei in graph[curr_node]:

                if nei not in visited:

                    node = GraphNode(nei, set(), set(), 0, 0, level)

                    node.parents.add(visited[curr_node])

                    visited[curr_node].children.add(node)

                    q.put(nei)

                    visited[nei] = node

                else:

                    if visited[curr_node].level != visited[nei].level and visited[nei] not in visited[curr_node].parents:

                        visited[curr_node].children.add(visited[nei])

                        visited[nei].parents.add(visited[curr_node])
        level += 1

    return visited


def assign_shortest_path(tree, root):

    # assign root 1

    tree[root].shortest_path = 1

    q = queue.Queue()

    q.put(tree[root])

    visited = set()

    visited.add(root)

    level_map = {}

    while not q.empty():

        curr_node = q.get()

        if curr_node.level not in level_map:

            level_map[curr_node.level] = set()

            level_map[curr_node.level].add(curr_node)

        else:

            level_map[curr_node.level].add(curr_node)

        # root node

        if len(curr_node.parents) == 0:

            curr_node.shortest_path = 1

        else:

            sp = 0

            for p in curr_node.parents:

                sp += (p.shortest_path)

            curr_node.shortest_path = sp

        for ch in curr_node.children:

            if ch.ids not in visited:

                visited.add(ch.ids)

                q.put(ch)

    return level_map


def get_edge(c, p):

    edge = [c.ids, p.ids]

    edge.sort()

    return tuple(edge)


def assign_outgoing_edge(node, edge_map):

    # credit for outgoing edges

    if len(node.parents) > 0:

        totoal_sp = 0.0

        for p in node.parents:

            totoal_sp += (p.shortest_path)

        for p in node.parents:

            edge = get_edge(node, p)

            edge_map[edge] = ( p.shortest_path / float(totoal_sp) ) * node.weight


def assign_credit(level_tree, edge_map):

    for pair in level_tree:

        nodes = pair[1]

        for node in nodes:

            # leaf

            if len(node.children) == 0:

                node.weight = 1.0

                # credit for outgoing edges

                assign_outgoing_edge(node, edge_map)

            else:

                edge_sum = 0.0

                for ch in node.children:

                    edge = get_edge(node, ch)

                    edge_sum += edge_map[edge]

                node.weight = 1 + edge_sum

                # credit for outgoing edges

                assign_outgoing_edge(node, edge_map)


def output_betweenness(of, btn):

    for ele in btn:

        line = str(ele[0]) + ', ' + str(ele[1])

        of.write(line + '\n')

    of.close()


def edge_remove(g, edge_r):

    g[edge_r[0][0]].discard(edge_r[0][1])

    g[edge_r[0][1]].discard(edge_r[0][0])


def calculate_q(graph, m, a):

    sum = 0.0

    for k, v in graph.items():

        for n in v:

            expected_edges = (len(graph[k]) * len(graph[n]) / (2 * m))

            if n in a[k]:

                sum = sum + (1 - expected_edges)

            else:

                sum = sum + (0 - expected_edges)

    return sum / (2.0 * m)


def calculate_betweenness(graph):
    # 1. for each node, build bfs tree

    tree_map = {}

    for k, v in graph.items():

        curr_tree = bfs(k, graph)

        tree_map[k] = curr_tree

    # 2. label each node by the number of shortest paths that reach it from the root. start by labeling the root 1.

    level_map = {}

    for k, v in tree_map.items():

        gn_tree = tree_map[k]

        level_map[k] = assign_shortest_path(gn_tree, k)

    # 3. calculate for each edge e the sum over all nodes Y of the
    # fraction of shortest paths from the root X to Y that go through e.

    credit_map = {}

    for k, v in level_map.items():

        edge_map = {}

        level_ordered = sorted(level_map[k].items(), key = operator.itemgetter(0), reverse = True)

        assign_credit(level_ordered, edge_map)

        credit_map[k] = edge_map

    betweenness_map = {}

    for k, v in credit_map.items():

        for e, w in v.items():

            if e not in betweenness_map:

                betweenness_map[e] = []

                betweenness_map[e].append(w)

            else:

                betweenness_map[e].append(w)

    for k, v in betweenness_map.items():

        betweenness_map[k] = (sum(v)) / 2.0

    btn_sorted = [(k, v) for k , v in betweenness_map.items()]

    btn_sorted.sort()

    btn_sorted.sort(key = lambda x : x[1], reverse=True)
    
    print(btn_sorted[:3])

    return btn_sorted

start = time.time()

sc = SparkContext().getOrCreate()

input_path = '/Users/haopengsong/Downloads/sample_data.csv'

output_path = '/Users/haopengsong/PycharmProjects/inf553hw4/betweenness.txt'

data = sc.textFile(input_path)

data_firstLine = data.take(1)

data = data.filter(lambda x : x != data_firstLine[0])

user_business = data.map(lambda x : x.split(",")) \
                    .map(lambda x : (x[0], [x[1]])) \
                    .reduceByKey(lambda a, b : a + b)

user_business = user_business.map(lambda x : (x[0], set(x[1])))

user_business_map = user_business.collectAsMap()

s1 = time.time()

graph = user_business.map(construct_graph) \
                    .filter(lambda x : len(x[1]) != 0) \
                    .collectAsMap()

print('\ntime: ' + str(time.time() - s1))



# output betweenness

output_file = open(output_path, 'w')

btn_sorted = calculate_betweenness(graph)

output_betweenness(output_file, btn_sorted)

# community detection
# 1. compute Q

# A = graph, adjacent matrix of the original graph

# new graph after remove one edge

m_num_edges = len(btn_sorted)

A = copy.deepcopy(graph)

qs = []

edge_highest_btn = btn_sorted[0]

for r in range(m_num_edges):

    q = 0

    if r == 0:

        edge_remove(graph, edge_highest_btn)

        q = calculate_q(graph, m_num_edges, A)

        qs.append(q)

        edge_highest_btn = calculate_betweenness(graph)[0]

    else:

        edge_remove(graph, edge_highest_btn)

        q = calculate_q(graph, m_num_edges, A)

        qs.append(q)

        if r != m_num_edges - 1:

            edge_highest_btn = calculate_betweenness(graph)[0]
            
    if r == 8:
        
        break

print('\ntime: ' + str(time.time() - s1))
# Out:
# time: 5.940282106399536
# [(('OHVhLKw_uIE7saIt_S-udw', 'UBUV0ElEvm8kgxZvcdDo2Q'), 4234.0), (('-7bM_DeL2Kj2CuYuVDsLNg', '-VNv58eLhbQpz787rcD8VA'), 3986.4873015873072), (('-VNv58eLhbQpz787rcD8VA', '8-S4AUMpk_3ZKQQbWgiwvQ'), 3857.0)]
# [(('OVnfDg-KuGWyDocYdKkmPQ', 'UBUV0ElEvm8kgxZvcdDo2Q'), 5017.533333333339), (('-7bM_DeL2Kj2CuYuVDsLNg', '-VNv58eLhbQpz787rcD8VA'), 3986.4873015873072), (('-VNv58eLhbQpz787rcD8VA', '8-S4AUMpk_3ZKQQbWgiwvQ'), 3857.0)]
# [(('-7bM_DeL2Kj2CuYuVDsLNg', '-VNv58eLhbQpz787rcD8VA'), 3986.4873015873072), (('-VNv58eLhbQpz787rcD8VA', '8-S4AUMpk_3ZKQQbWgiwvQ'), 3857.0), (('-VNv58eLhbQpz787rcD8VA', 'WPcEBAbrPZxvCGlvH9XLsQ'), 3724.0)]
# [(('--YhjyV-ce1nFLYxP49C5A', '-VNv58eLhbQpz787rcD8VA'), 7656.0), (('-VNv58eLhbQpz787rcD8VA', '8-S4AUMpk_3ZKQQbWgiwvQ'), 3857.0), (('-VNv58eLhbQpz787rcD8VA', 'WPcEBAbrPZxvCGlvH9XLsQ'), 3724.0)]
# [(('---1lKK3aKOuomHnwAkAow', '--YhjyV-ce1nFLYxP49C5A'), 1053.1345938316183), (('--YhjyV-ce1nFLYxP49C5A', '-PHC1ulwHkY4LEmMqmFwPg'), 821.098648344357), (('--YhjyV-ce1nFLYxP49C5A', '-7bM_DeL2Kj2CuYuVDsLNg'), 743.2490653250371)]
# [(('--YhjyV-ce1nFLYxP49C5A', '-PHC1ulwHkY4LEmMqmFwPg'), 1109.7530115238555), (('--YhjyV-ce1nFLYxP49C5A', '-7bM_DeL2Kj2CuYuVDsLNg'), 1014.4607665139637), (('-9b4s874f_CnznTu4JorRg', '-WMhXcdzVV-o3PN06-yzRA'), 787.7840921440022)]
# [(('--YhjyV-ce1nFLYxP49C5A', '-7bM_DeL2Kj2CuYuVDsLNg'), 1460.028017407429), (('-9b4s874f_CnznTu4JorRg', '-WMhXcdzVV-o3PN06-yzRA'), 954.8900812422863), (('--YhjyV-ce1nFLYxP49C5A', '-kRQLEDxrEBVNXImyAt_ug'), 700.3543189653485)]
# [(('--YhjyV-ce1nFLYxP49C5A', '-kRQLEDxrEBVNXImyAt_ug'), 1497.9930470114673), (('-9b4s874f_CnznTu4JorRg', '-WMhXcdzVV-o3PN06-yzRA'), 1411.7573365231267), (('--2vR0DIsmQ6WfcSzKWigw', '-kRQLEDxrEBVNXImyAt_ug'), 1328.2813340168598)]
# [(('-9b4s874f_CnznTu4JorRg', '-WMhXcdzVV-o3PN06-yzRA'), 2190.550436037393), (('--2vR0DIsmQ6WfcSzKWigw', '-WMhXcdzVV-o3PN06-yzRA'), 1110.5335604009522), (('---1lKK3aKOuomHnwAkAow', '-_2h2cJlBOWAYrfplMU-Cg'), 781.3581153146362)]
# [(('---1lKK3aKOuomHnwAkAow', '-_2h2cJlBOWAYrfplMU-Cg'), 1390.14006224777), (('-9b4s874f_CnznTu4JorRg', '0FVcoJko1kfZCrJRfssfIA'), 1344.219875504463), (('---1lKK3aKOuomHnwAkAow', '--2vR0DIsmQ6WfcSzKWigw'), 1256.8697543538703)]
#
# time: 11.43849802017212

# %%
sum1 = 0
for k, v in graph.items():

    sum1 += len(v)
    
sum1
# Out:
# 978

# %%
sum2 = 0
for k, v in A.items():
    
    sum2 += len(v)

# %%
sum2
# Out:
# 996
